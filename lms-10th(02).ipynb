# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\soumya kemidi\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\soumya kemidi\anaconda3\lib\site-packages (from PyPDF2) (4.12.2)

# %%
import PyPDF2
from PyPDF2 import PdfFileReader

# %%
#Creating a pdf file object

pdf = open("file1pdf.pdf","rb")

 

#creating pdf reader object

pdf_reader = PyPDF2.PdfReader(pdf)

 

#checking number of pages in a pdf file

print("Number of pages:",len(pdf_reader.pages))

 

#creating a page object

page = pdf_reader.pages[1]

#finally extracting text from the page

print(page.extract_text())

 

#closing the pdf file

pdf.close()
# Out:
# Number of pages: 35
#
#
#  Development  Plan for Greater Mumbai 2014‐2034
# Acknowledgements
# The Consultant  wishes to thank the following  individuals  from the Municipal  Corporation  of
# Greater Mumbai for their invaluable  support, insights and contributions  towards ‘Working  Paper 1
# – Preparation  of Base Map’ for the preparation  of the Development  Plan for Greater Mumbai
# 2014‐34.
#  Mr. Subodh Kumar, IAS, Municipal  Commissioner;
#  Mr. Rajeev Kuknoor, Chief Engineer Development  Plan;
#  Mr. Sudhir Ghate, Deputy Chief Engineer Development  Plan;
#  Mr. A.G. Marathe, Deputy Chief Engineer Development  Plan;
#  Mr. R. Balachandran,  Executive  Engineer and Town Planning Officer, Development  Plan.
#  Our gratitude  to the following  experts for their invaluable  insights and support:
# 
# Mr. V.K Phatak, Former Chief Town Planner (MMRDA);
#  Mr. A.N Kale, Former Chief Engineer, (DP);
#  Mr. A. S Jain Former Dy. Chief Engineer, (DP).
#  We wish to especially  thank MCGM officers, Mr. Jagdish Talreja, Mr. Dinesh Naik, Mr. Hiren
# Daftardar,  Ms. Anita Naik for their continual  support since the
#  beginning  of the project and their
# help towards familiarization  and data collection.  They have been instrumental  in helping to
# contact various MCGM departments  as well as in helping to establish contact with personnel  from
# other government  departments  and organizations.  Many thanks for the MCGM team, for
# deploying  personnel,  particularly  Mr. Prasad Gharat, on extensive  field visits that have helped in
# understanding  actual ground conditions.
#
# We apologize  if we have inadvertently  omitted anyone to whom acknowledgement  is due. We hope
# and anticipate  the work's usefulness  for the intended purpose.

# %%
import PyPDF2, urllib , nltk
from io import BytesIO
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
#Reading the PDF
wFile = urllib.request.urlopen('http://www.udri.org/pdf/02%20working%20paper%201.pdf')
pdfreader = PyPDF2.PdfReader(BytesIO(wFile.read()))

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\soumya
# [nltk_data]     kemidi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
#extracting page 2 of the docuemnt
pageObj = pdfreader.pages[2]
page2 = pageObj.extract_text()
#Cleaning the text
punctuations = ['(',')',';',':','[',']',',','...','.']
tokens = word_tokenize(page2)
stop_words = stopwords.words('english')
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
keywords
# Out:
# ['Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐2034',
#  'Table',
#  'Contents',
#  'The',
#  'Consultant',
#  'wishes',
#  'thank',
#  'following',
#  'individuals',
#  'Municipal',
#  'Corporation',
#  'Greater',
#  'Mumbai',
#  'invaluable',
#  'support',
#  'insights',
#  'contributions',
#  'towards',
#  '‘',
#  'Working',
#  'Paper',
#  '1',
#  '–',
#  'Preparation',
#  'Base',
#  'Map',
#  '’',
#  'preparation',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐34',
#  '.............................................................................................................................',
#  '..............',
#  '3',
#  'Our',
#  'gratitude',
#  'following',
#  'experts',
#  'invaluable',
#  'insights',
#  'support',
#  '............................',
#  '3',
#  'We',
#  'wish',
#  'especially',
#  'thank',
#  'MCGM',
#  'officers',
#  'Mr.',
#  'Jagdish',
#  'Talreja',
#  'Mr.',
#  'Dinesh',
#  'Naik',
#  'Mr.',
#  'Hiren',
#  'Daftardar',
#  'Ms.',
#  'Anita',
#  'Naik',
#  'continual',
#  'support',
#  'since',
#  'beginning',
#  'project',
#  'help',
#  'towards',
#  'familiarization',
#  'data',
#  'collection',
#  'They',
#  'instrumental',
#  'helping',
#  'contact',
#  'various',
#  'MCGM',
#  'departments',
#  'well',
#  'helping',
#  'establish',
#  'contact',
#  'personnel',
#  'government',
#  'departments',
#  'organizations',
#  'Many',
#  'thanks',
#  'MCGM',
#  'team',
#  'deploying',
#  'personnel',
#  'particularly',
#  'Mr.',
#  'Prasad',
#  'Gharat',
#  'extensive',
#  'field',
#  'visits',
#  'helped',
#  'understanding',
#  'actual',
#  'ground',
#  'conditions',
#  '........................................................................................',
#  '3',
#  'BEST',
#  '...............................................................................................................................',
#  '.................',
#  '5',
#  'Brihanmumbai',
#  'Electric',
#  'Supply',
#  'Transport',
#  'Undertaking',
#  '..............................................................',
#  '5',
#  'CIDCO',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'City',
#  'Industrial',
#  'Development',
#  'Corporation',
#  '...............................................................................',
#  '5',
#  'CTP',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Comprehensive',
#  'Transportation',
#  'Plan',
#  '...............................................................................................',
#  '5',
#  'DP',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Development',
#  'Plan',
#  '..........................................................................................................................',
#  '5',
#  'DPGM34',
#  '...............................................................................................................................',
#  '..........',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2034',
#  '.......................................................................................',
#  '5',
#  'DCR',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Development',
#  'Control',
#  'Regulations',
#  '...................................................................................................',
#  '5',
#  'DGPS',
#  '...........................................................................................................................',
#  '....................',
#  '5',
#  'Digital',
#  'Global',
#  'Positioning',
#  'System',
#  '...................................................................................................',
#  '5',
#  'DPGM',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '...........................................................................................',
#  '5',
#  'ELU',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Existing',
#  'Land',
#  'use',
#  '.............................................................................................................................',
#  '5',
#  'FSI',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Floor',
#  'Space',
#  'Index',
#  '............................................................................................................................',
#  '5',
#  'GIS',
#  '...............................................................................................................................',
#  '...................',
#  '5']

# %%
name_list = list()
check =  ['Mr.','Mrs.','Ms.']
for idx, token in enumerate(tokens):
    if token.startswith(tuple(check)) and idx < (len(tokens)-1):
        name = token + tokens[idx+1] + ' ' +  tokens[idx+2]
        name_list.append(name)
print(name_list)
# Out:
# ['Mr.Jagdish Talreja', 'Mr.Dinesh Naik', 'Mr.Hiren Daftardar', 'Ms.Anita Naik', 'Mr.Prasad Gharat']

# %%
wFile.close()

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#      -------------------------------------- 244.3/244.3 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=3.1.0 in c:\users\soumya kemidi\anaconda3\lib\site-packages (from python-docx) (4.9.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\soumya kemidi\anaconda3\lib\site-packages (from python-docx) (4.12.2)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2

# %%
import docx

# %%
#Creating a word file object

doc = open("report writing[1].docx","rb")

#creating word reader object

document = docx.Document(doc)

# %%
docu=""

for para in document.paragraphs:

    docu += para.text

#to see the output call docu

print(docu)
# Out:
# PROJECT REPORTONUnveiling the Power of Artificial IntelligenceA report submitted in partial fulfillment of the requirements of ‘English for Technical Communication and Employability Skills’ for the year 2024 Submitted by :GROUP 1                                                                           Submitted to:                                              Ms.Ida Fernandez                                             Associate Professor                                            Department of English                                          Malla Reddy University                                               ACKNOWLEDGEMENTWe are extremely thankful to Dr.Thayyaba Khatoon professor/HOD, Dept of AIML for all the timely support for providing the working facilities in the college. We are extremely thankful and indebted to our internal guide,Ms.Ida Fernandez Asst Professor,Dept of H&S,for his/her constant guidance, continuous advice, Encouragement and moral support throughout the project.Finally, we would also like to thank our parents, team members, and all the faculty/staff of MRUH who helped us directly or indirectly, for their cooperation in completing the field study.                                    TABLE OF CONTENTS                                                       CERTIFICATE OF COMPLETIONThis is to certify that Sowmya (247), Jai Vivek(248), Saiteja(249), Sukanya(250), Santhosh Nikhil (254), Niharika(255), Jaswanth(256), Shashank (257), Kamalesh (258) students of Malla Reddy University, have successfully completed a project titled.Assessing Resume Writing Skills and mistakes among II year Engineering Students of Malla Reddy University- A Report under the guidance and supervisions of Ms . Ida Fernandez, Asst. Professor, Department of English, MRUH.During the project, the students demonstrated exceptional technical skills, creativity, and problem-solving abilities, and contributed significantly to the success of the project. They Also showed excellent teamwork and communication skills and worked effectively with other team members.We would like to express our sincere appreciation to [Student Names] for their hard work and dedication throughout the project. We wish them continued success in their future endeavors.Signed:Mrs. Ida Fernandez Assistant Professor Department of English Malla Reddy University.Date:1st March, 2024Abstract:Artificial Intelligence (AI) stands at the forefront of technological innovation, offering unprecedented potential to revolutionize industries, reshape economies, and improve quality of life. This abstract explores the multifaceted power of AI, elucidating its transformative impact across various sectors and its potential to empower individuals and societies worldwide.At its core, AI encompasses a diverse set of technologies, including machine learning, natural language processing, computer vision, and robotics, which enable machines to perform tasks that traditionally require human intelligence. By harnessing vast amounts of data and computational power, AI algorithms can analyze patterns, make predictions, and generate insights with remarkable speed and accuracy.In healthcare, AI is driving advancements in personalized medicine, disease diagnosis, and treatment optimization, facilitating early detection, precision therapies, and improved patient outcomes. Through AI-powered diagnostic tools, predictive analytics, and virtual care platforms, healthcare providers can deliver more efficient, accessible, and patient-centric care. In finance, AI is transforming banking, investment, and risk management processes, enhancing fraud detection, algorithmic trading, and customer service experiences. AI-driven algorithms analyze market trends, customer behavior, and financial data in real-time, enabling more informed decision-making, personalized recommendations, and risk mitigation strategies.In manufacturing, AI-powered automation, robotics, and predictive maintenance are optimizing production proces ...

# %%
#  output paragraph number and paragraph content 
for i in range(len(document.paragraphs)):
    print("The content of the paragraph "+ str(i)+" is ：" + document.paragraphs[i].text+"\n")
# Out:
# The content of the paragraph 0 is ：PROJECT REPORT
#
# The content of the paragraph 1 is ：ON
#
# The content of the paragraph 2 is ：Unveiling the Power of Artificial Intelligence
#
# The content of the paragraph 3 is ：
#
# The content of the paragraph 4 is ：A report submitted in partial fulfillment of the requirements of ‘English for Technical Communication and Employability Skills’ for the year 2024
#
# The content of the paragraph 5 is ：
#
# The content of the paragraph 6 is ：
#
# The content of the paragraph 7 is ：
#
# The content of the paragraph 8 is ：Submitted by :GROUP 1
#
# The content of the paragraph 9 is ：
#
# The content of the paragraph 10 is ：
#
# The content of the paragraph 11 is ：
#
# The content of the paragraph 12 is ：
#
# The content of the paragraph 13 is ：
#
# The content of the paragraph 14 is ：
#
# The content of the paragraph 15 is ：                                                  Submitted to:
#
# The content of the paragraph 16 is ：                                              Ms.Ida Fernandez
#
# The content of the paragraph 17 is ：                                             Associate Professor
#
# The content of the paragraph 18 is ：                                           Department of English
#
# The content of the paragraph 19 is ：                                          Malla Reddy University
#
# The content of the paragraph 20 is ：
#
# The content of the paragraph 21 is ：
#
# The content of the paragraph 22 is ：
#
# The content of the paragraph 23 is ：
#
# The content of the paragraph 24 is ：
#
# The content of the paragraph 25 is ：
#
# The content of the paragraph 26 is ：
#
# The content of the paragraph 27 is ：
#
# The content of the paragraph 28 is ：
#
# The content of the paragraph 29 is ：
#
# The content of the paragraph 30 is ：
#
# The content of the paragraph 31 is ：
#
# The content of the paragraph 32 is ：                                               ACKNOWLEDGEMENT
#
# The content of the paragraph 33 is ：
#
# The content of the paragraph 34 is ：We are extremely thankful to Dr.Thayyaba Khatoon professor/HOD, Dept of AIML for all the timely support for providing the working facilities in the college.
#
# The content of the paragraph 35 is ：
#
# The content of the paragraph 36 is ：We are extremely thankful and indebted to our internal guide,Ms.Ida Fernandez Asst Professor,Dept of H&S,for his/her constant guidance, continuous advice, Encouragement and moral support throughout the project.
#
# The content of the paragraph 37 is ：
#
# The content of the paragraph 38 is ：Finally, we would also like to thank our parents, team members, and all the faculty/staff of MRUH who helped us directly or indirectly, for their cooperation in completing the field study.
#
# The content of the paragraph 39 is ：
#
# The content of the paragraph 40 is ：
#
# The content of the paragraph 41 is ：
#
# The content of the paragraph 42 is ：
#
# The content of the paragraph 43 is ：                                   TABLE OF CONTENTS
#
# The content of the paragraph 44 is ：
#
# The content of the paragraph 45 is ：
#
# The content of the paragraph 46 is ：
#
# The content of the paragraph 47 is ：                           CERTIFICATE OF COMPLETION
#
# The content of the paragraph 48 is ：
#
# The content of the paragraph 49 is ：
#
# The content of the paragraph 50 is ：This is to certify that Sowmya (247), Jai Vivek(248), Saiteja(249), Sukanya(250), Santhosh Nikhil (254), Niharika(255), Jaswanth(256), Shashank (257), Kamalesh (258) students of Malla Reddy University, have successfully completed a project titled.
#
# The content of the paragraph 51 is ：
#
# The content of the paragraph 52 is ：Assessing Resume Writing Skills and mistakes among II year Engineering Students of Malla Reddy University- A Report under the guidance and supervisions of Ms . Ida Fernandez, Asst. Professor, Department of English, MRUH.
#
# The content of the paragraph 53 is ：
#
# The content of the paragraph 54 is ：During the project, the students demonstrated exceptional technical skills, creativity, and problem-solving abilities, and contributed significantly to the success of the project. They Also showed excellent teamwork and communication skills and worked effectively with other team members.
#
# The content of the paragraph 55 is ：
#
# The content of the paragraph 56 is ：We would like to express our sincere appreciation to [Student Names] for their hard work and dedication throughout the project. We wish them continued success in their future endeavors.
#
# The content of the paragraph 57 is ：
#
# The content of the paragraph 58 is ：Signed:
#
# The content of the paragraph 59 is ：Mrs. Ida Fernandez
#
# The content of the paragraph 60 is ：Assistant Professor
#
# The content of the paragraph 61 is ：Department of English
#
# The content of the paragraph 62 is ：Malla Reddy University.
#
# The content of the paragraph 63 is ：
#
# The content of the paragraph 64 is ：
#
# The content of the paragraph 65 is ：
#
# The content of the paragraph 66 is ：Date:1st March, 2024
#
# The content of the paragraph 67 is ：Abstract:
#
# The content of the paragraph 68 is ：
#
# The content of the paragraph 69 is ：Artificial Intelligence (AI) stands at the forefront of technological innovation, offering unprecedented potential to revolutionize industries, reshape economies, and improve quality of life. This abstract explores the multifaceted power of AI, elucidating its transformative impact across various sectors and its potential to empower individuals and societies worldwide.
#
# The content of the paragraph 70 is ：
#
# The content of the paragraph 71 is ：At its core, AI encompasses a diverse set of technologies, including machine learning, natural language processing, computer vision, and robotics, which enable machines to perform tasks that traditionally require human intelligence. By harnessing vast amounts of data and computational power, AI algorithms can analyze patterns, make predictions, and generate insights with remarkable speed and accuracy.
#
# The content of the paragraph 72 is ：
#
# The content of the paragraph 73 is ：In healthcare, AI is driving advancements in personalized medicine, disease diagnosis, and treatment optimization, facilitating early detection, precision therapies, and improved patient outcomes. Through AI-powered diagnostic tools, predictive analytics, and virtual care platforms, healthcare providers can deliver more efficient, accessible, and patient-centric care.
#
# The content of the paragraph 74 is ：
#
# The content of the paragraph 75 is ：In finance, AI is transforming banking, investment, and risk management processes, enhancing fraud detection, algorithmic trading, and customer service experiences. AI-driven algorithms analyze market trends, customer behavior, and financial data in real-time, enabling more informed decision-making, personalized recommendations, and risk mitigation strategies.
#
# The content of the paragraph 76 is ：
#
# The content of the paragraph 77 is ：In manufacturing, AI-powered automation, robotics, and predictive maintenance are optimizing production processes, improving efficiency, and reducing operational costs. AI algorithms analyze sensor data, monitor equipment performance, and predict maintenance needs, leading to increased uptime, quality, and scalability for manufacturing operations.
#
# The content of the paragraph 78 is ：
#
# The content of the paragraph 79 is ：
#
# The content of the paragraph 80 is ：
#
# The content of the paragraph 81 is ：
#
# The content of the paragraph 82 is ：
#
# The content of the paragraph 83 is ：Introduction:
#
# The content of the paragraph 84 is ：In the fast-paced realm of technology, Artificial Intelligence (AI) stands as a beacon of innovation, revolutionizing industries and shaping the future of humanity. With its ability to mimic human intelligence, process vast amounts of data, and adapt to changing environments, AI has transcended from mere science fiction to an integral part of our daily lives.
#
# The content of the paragraph 85 is ：
#
# The content of the paragraph 86 is ：This introduction will delve into the intricacies of AI, exploring its origins, evolution, and limitless potential. From machine learning algorithms to neural networks, AI has propelled us into an era where the impossible becomes achievable and the unimaginable becomes reality.
#
# The content of the paragraph 87 is ：
#
# The content of the paragraph 88 is ：AI (Artificial Intelligence) marks a significant advancement in technology, enabling machines to perform tasks that typically require human intelligence. AI encompasses various subfields like machine learning, natural language processing, computer vision, and robotics. It has applications across industries, including healthcare, finance, transportation, and entertainment, revolutionizing processes, improving efficiency, and creating new opportunities. However, ethical considerations regarding AI's impact on society, privacy, and job displacement remain subjects of ongoing debate and regulation.
#
# The content of the paragraph 89 is ：
#
# The content of the paragraph 90 is ：
#
# The content of the paragraph 91 is ：
#
# The content of the paragraph 92 is ：
#
# The content of the paragraph 93 is ：Objectives :
#
# The content of the paragraph 94 is ：
#
# The content of the paragraph 95 is ：1. Automation: AI aims to automate repetitive tasks and processes, freeing up human resources for more complex and creative endeavors. This leads to increased efficiency, productivity, and cost-effectiveness across various industries.
#
# The content of the paragraph 96 is ：
#
# The content of the paragraph 97 is ：2. Decision Making: By analyzing vast amounts of data and extracting meaningful insights, AI systems facilitate informed decision-making. Whether in finance, healthcare, or logistics, AI empowers organizations to make smarter choices with greater accuracy and speed.
#
# The content of the paragraph 98 is ：
#
# The content of the paragraph 99 is ：3. Problem Solving:AI is designed to tackle complex problems that may be too challenging or time-consuming for humans to solve alone. Through advanced algorithms and computational power, AI can find optimal solutions to intricate problems in fields such as engineering, science, and optimization.
#
# The content of the paragraph 100 is ：
#
# The content of the paragraph 101 is ：4. Personalization:AI enables personalized experiences by understanding user preferences, behaviors, and patterns. From recommendation systems in e-commerce to adaptive learning platforms in education, AI tailors interactions to individual needs, enhancing user satisfaction and engagement.
#
# The content of the paragraph 102 is ：
#
# The content of the paragraph 103 is ：5. Innovation:AI fosters innovation by pushing the boundaries of what is possible. Through research and development, AI pioneers new technologies, fuels breakthroughs in various domains, and drives continuous progress towards achieving greater intelligence and autonomy.
#
# The content of the paragraph 104 is ：
#
# The content of the paragraph 105 is ：6. Enhanced Communication:  Natural Language Processing (NLP) and conversational AI enable machines to understand and generate human-like language, facilitating seamless communication between humans and computers. This leads to improved accessibility, user experience, and interaction with technology.
#
# The content of the paragraph 106 is ：
#
# The content of the paragraph 107 is ：
#
# The content of the paragraph 108 is ：Challenges and Concerns of Artificial Intelligence:
#
# The content of the paragraph 109 is ：
#
# The content of the paragraph 110 is ：1. Ethical Dilemmas: AI raises profound ethical questions regarding its impact on society, privacy, and human rights. Issues such as algorithmic bias, data privacy, and the use of AI in autonomous weapons systems pose complex ethical dilemmas that require careful consideration and regulation.
#
# The content of the paragraph 111 is ：
#
# The content of the paragraph 112 is ：2. Job Displacement: The automation enabled by AI has the potential to disrupt labor markets and lead to job displacement, particularly in sectors where routine tasks can be easily automated. Addressing the socioeconomic consequences of AI-driven automation, such as unemployment and income inequality, is a significant challenge for policymakers and stakeholders.
#
# The content of the paragraph 113 is ：
#
# The content of the paragraph 114 is ：3. Bias and Fairness: AI systems can perpetuate and amplify biases present in the data used to train them, leading to discriminatory outcomes. Addressing bias and ensuring fairness in AI algorithms is crucial to building trust and promoting equitable access to AI-driven technologies.
#
# The content of the paragraph 115 is ：
#
# The content of the paragraph 116 is ：4. Transparency and Accountability: The complexity of AI algorithms and their opaque decision-making processes raise concerns about accountability and transparency. Ensuring that AI systems are transparent, explainable, and accountable for their decisions is essential for building trust and mitigating the risk of unintended consequences.
#
# The content of the paragraph 117 is ：
#
# The content of the paragraph 118 is ：5. Security Risks: AI systems are susceptible to various security threats, including adversarial attacks, data breaches, and manipulation of AI-generated content. Securing AI systems against cyber threats and ensuring their resilience to malicious attacks are critical challenges for cybersecurity professionals and researchers.
#
# The content of the paragraph 119 is ：
#
# The content of the paragraph 120 is ：6. Regulatory Challenges: The rapid advancement of AI technology outpaces the development of regulatory frameworks to govern its use. Establishing appropriate regulations and standards to address the ethical, legal, and safety implications of AI is essential for harnessing its potential while mitigating risks.
#
# The content of the paragraph 121 is ：
#
# The content of the paragraph 122 is ：
#
# The content of the paragraph 123 is ：
#
# The content of the paragraph 124 is ：
#
# The content of the paragraph 125 is ：Data Collection in Artificial Intelligence:
#
# The content of the paragraph 126 is ：1.Identifying Data Sources: AI projects start by identifying relevant sources of data, which can include structured data from databases, unstructured data from text, images, and videos, and semi-structured data from sources like web pages or social media.
#
# The content of the paragraph 127 is ：
#
# The content of the paragraph 128 is ：2.Accessing Data: Once identified, accessing the data involves obtaining permissions, licenses, or agreements necessary to collect and use the data legally and ethically. This may involve partnering with data providers, accessing public datasets, or collecting proprietary data through surveys, sensors, or other means.
#
# The content of the paragraph 129 is ：
#
# The content of the paragraph 130 is ：3.Data Scraping and Crawling: For web-based data sources, data scraping and crawling techniques are used to extract information from websites, APIs, or online databases. This involves writing scripts or using specialized tools to systematically gather data according to predefined criteria.
#
# The content of the paragraph 131 is ：
#
# The content of the paragraph 132 is ：4.Data Acquisition: In cases where data is generated in real-time, such as sensor data from IoT devices or streaming data from social media, data acquisition systems are used to capture and store the data as it is generated. This may involve setting up data pipelines or streaming platforms to handle large volumes of data efficiently.
#
# The content of the paragraph 133 is ：
#
# The content of the paragraph 134 is ：
#
# The content of the paragraph 135 is ：Data Analysis in HealthCare:
#
# The content of the paragraph 136 is ：
#
# The content of the paragraph 137 is ：1.Digital Health Revolution: The period from 2022 to 2030 is likely to witness a significant digital transformation in healthcare in India. This includes the widespread adoption of electronic health records (EHRs), telemedicine services, health apps, and wearable devices. These technologies will improve access to healthcare services, facilitate remote patient monitoring, and enable better data management for healthcare providers.
#
# The content of the paragraph 138 is ：
#
# The content of the paragraph 139 is ：2.Big Data and Analytics: With the increasing digitization of healthcare data, there will be a wealth of information available for analysis. Big data analytics will play a crucial role in extracting insights from this data to improve patient outcomes, optimize resource allocation, and support evidence-based decision-making by healthcare providers and policymakers.
#
# The content of the paragraph 140 is ：
#
# The content of the paragraph 141 is ：3.Public Health Surveillance: Effective disease surveillance systems will be essential for early detection and containment of infectious disease outbreaks. Data analysis techniques such as predictive modeling, spatial analysis, and real-time monitoring will be used to track the spread of diseases, identify hotspots, and implement timely intervention strategies to control epidemics.
#
# The content of the paragraph 142 is ：
#
# The content of the paragraph 143 is ：
#
# The content of the paragraph 144 is ：
#
# The content of the paragraph 145 is ：
#
# The content of the paragraph 146 is ：
#
# The content of the paragraph 147 is ：
#
# The content of the paragraph 148 is ：
#
# The content of the paragraph 149 is ：
#
# The content of the paragraph 150 is ：
#
# The content of the paragraph 151 is ：Methodology:
#
# The content of the paragraph 152 is ：
#
# The content of the paragraph 153 is ：1.Data Collection:The first step in AI methodology involves gathering relevant data from various sources. This data serves as the foundation for training AI models and includes structured data from databases, unstructured data from text, images, and videos, and sensor data from IoT devices.
#
# The content of the paragraph 154 is ：2.Data Preprocessing: Once the data is collected, it undergoes preprocessing to clean, transform, and prepare it for analysis. This involves tasks such as data cleaning to remove errors and outliers, feature scaling to normalize data, and feature extraction to extract meaningful patterns and insights.
#
# The content of the paragraph 155 is ：3.Feature Engineering: Feature engineering is the process of selecting, transforming, and creating new features from the raw data to improve the performance of AI models. This may involve techniques such as dimensionality reduction, feature selection, and generating new features through mathematical transformations or domain expertise.
#
# The content of the paragraph 156 is ：4.Model Selection: AI practitioners choose appropriate algorithms and models based on the nature of the problem, the type of data, and the desired outcomes. Common AI techniques include machine learning algorithms such as linear regression, decision trees, support vector machines, and deep learning models such as convolutional neural networks (CNNs) and recurrent neural networks (RNNs).
#
# The content of the paragraph 157 is ：5.Training: The selected AI model is trained using labeled data, where the model learns to make predictions or decisions by adjusting its parameters to minimize a predefined loss function. Training involves iterative optimization algorithms such as gradient descent, backpropagation, and stochastic gradient descent, which update the model's parameters based on the difference between predicted and actual outcomes.
#
# The content of the paragraph 158 is ：6.Evaluation: After training, the performance of the AI model is evaluated using validation data to assess its accuracy, precision, recall, and other relevant metrics. This helps AI practitioners fine-tune the model and identify areas for improvement before deploying it in real-world applications.
#
# The content of the paragraph 159 is ：7.Deployment:Once the AI model meets the performance criteria, it is deployed in production environments to make predictions, classify data, or automate tasks. Deployment involves integrating the AI model into existing systems, monitoring its performance, and ensuring scalability, reliability, and security.
#
# The content of the paragraph 160 is ：
#
# The content of the paragraph 161 is ：Conclusion:
#
# The content of the paragraph 162 is ：
#
# The content of the paragraph 163 is ：As we navigate the ever-evolving landscape of technology, Artificial Intelligence (AI) emerges as a transformative force with boundless potential to shape our future. From revolutionizing industries to enhancing human capabilities, AI holds the promise of ushering in a new era of innovation, efficiency, and progress.
#
# The content of the paragraph 164 is ：
#
# The content of the paragraph 165 is ：In this journey through the realm of AI, we have explored its origins, methodologies, and objectives, witnessing its remarkable ability to mimic human intelligence, analyze vast amounts of data, and adapt to changing environments. We have delved into the challenges and concerns surrounding AI, from ethical dilemmas to job displacement, recognizing the importance of responsible development and deployment of AI technologies.
#
# The content of the paragraph 166 is ：
#
# The content of the paragraph 167 is ：Despite the complexities and uncertainties that accompany AI, the opportunities it presents are profound. By harnessing the power of AI to automate tasks, make informed decisions, and solve complex problems, we can unlock new frontiers of possibility and address some of the greatest challenges facing humanity.
#
# The content of the paragraph 168 is ：
#
# The content of the paragraph 169 is ：As we look to the future, it is imperative that we approach AI with a sense of responsibility, ethics, and foresight. By fostering collaboration, innovation, and inclusivity, we can harness the transformative potential of AI to create a better world for generations to come.
#
# The content of the paragraph 170 is ：
#
# The content of the paragraph 171 is ：

# %%
# Install and import all the necessary libraries

# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\soumya kemidi\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\soumya kemidi\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
import urllib.request as urllib2

from bs4 import BeautifulSoup

# %%
response = urllib2.urlopen('https://en.wikipedia.org/wiki/Natural_language_processing')

html_doc = response.read()

# %%
#Parsing

soup = BeautifulSoup(html_doc, 'html.parser')

# Formating the parsed html file

strhtm = soup.prettify()

# Print few lines

print (strhtm[:5000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Natural language processing - Wikipedia
#   </title>
#   <script>
#    (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy",
# "wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"636a811e-8840-4aad-8507-bd50facda618","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Natural_language_processing","wgTitle":"Natural language processing","wgCurRevisionId":1274942014,"wgRevisionId":1274942014,"wgArticleId":21652,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All accuracy disputes","Accuracy disputes from December 2013","Harv and Sfn no-target errors","CS1 errors: periodical ignored","CS1 maint: location","Articles with short description","Short description is different from Wikidata","Articles needing additional references from May 2024","All articles needing additional references","All articles with unsourced statements","Articles with unsourced statements from May 2024","Commons category link from Wikidata",
# "Natural language processing","Computational fields of study","Computational linguistics","Speech recognition"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Natural_language_processing","wgRelevantArticleId":21652,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":60000,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,
# "wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q30642","wgCheckUserClientHintsHeadersJsApi":["brands","architecture","bitness","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.math.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.makeCollapsible.styles":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.scribunto.logs","site",
# "mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.bootstrap","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visu
